# %% [markdown]
# # Multiple Linear Regression
# ## Geely Auto Case Study
#
# #### Problem Statement:
#
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit
# there and producing cars locally to give competition to their US and European counterparts.
#
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends.
# Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those
# may be very different from the Chinese market. The company wants to know:
#
# - Which variables are significant in predicting the price of a car
# - How well those variables describe the price of a car
#
# **So interpretation is important!**

# %% [markdown]
# ## Step 1: Reading and Understanding the Data
#
# Let us first import NumPy and Pandas and read the Car dataset

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

# %%
car = pd.read_csv("C:/Users/hp/Desktop/CarPrice_Assignment.csv")

# %%
# Check the head of the dataset
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase   ...     enginesize  \
# 0  convertible        rwd          front       88.6   ...            130
# 1  convertible        rwd          front       88.6   ...            130
# 2    hatchback        rwd          front       94.5   ...            152
# 3        sedan        fwd          front       99.8   ...            109
# 4        sedan        4wd          front       99.4   ...            136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# We will check for duplicate values in dataset

# %%
sum(car.duplicated(subset = 'car_ID')) == 0
# Out:
# True

# %% [markdown]
# We will check for NA values in dataset

# %%
print (car.isnull().values.any())
# Out:
# False

# %% [markdown]
# Inspect the various aspects of the car dataframe

# %%
car.shape
# Out:
# (205, 26)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# car_ID              205 non-null int64
# symboling           205 non-null int64
# CarName             205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# horsepower          205 non-null int64
# peakrpm             205 non-null int64
# citympg             205 non-null int64
# highwaympg          205 non-null int64
# price               205 non-null float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.7+ KB

# %%
car.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %% [markdown]
# ## Step 2: Visualising the Data
#
# Let's now spend some time doing what is arguably the most important step - **understanding the data**.
# - If there is some obvious multicollinearity going on, this is the first place to catch it
# - Here's where you'll also identify if some predictors directly have a strong association with the outcome variable
#
# We'll visualise our data using `matplotlib` and `seaborn`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Visualising Numeric Variables
#
# Let's make a pairplot of all the numeric variables

# %% [markdown]
# #### Visualising Categorical Variables
#
# As you might have noticed, there are a few categorical variables as well. Let's make a boxplot for some of these variables.

# %% [markdown]
# #### Creating Column 'CarCompany'  by spliting the 'CarName' coulmn for better analysis and then we will delete the 'CarName' coulmn for that is no longer useful for analysis

# %%
car1 = car["CarName"].str.split(" ", n = 0, expand = True) 
car["CarCompany"]= car1[0]

# %%
car.CarCompany = car['CarCompany'].str.lower()
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase     ...       fuelsystem  \
# 0  convertible        rwd          front       88.6     ...             mpfi
# 1  convertible        rwd          front       88.6     ...             mpfi
# 2    hatchback        rwd          front       94.5     ...             mpfi
# 3        sedan        fwd          front       99.8     ...             mpfi
# 4        sedan        4wd          front       99.4     ...             mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# 0       3.47    2.68               9.0        111    5000       21         27
# 1       3.47    2.68               9.0        111    5000       21         27
# 2       2.68    3.47               9.0        154    5000       19         26
# 3       3.19    3.40              10.0        102    5500       24         30
# 4       3.19    3.40               8.0        115    5500       18         22
#
#      price   CarCompany
# 0  13495.0  alfa-romero
# 1  16500.0  alfa-romero
# 2  16500.0  alfa-romero
# 3  13950.0         audi
# 4  17450.0         audi
#
# [5 rows x 27 columns]

# %% [markdown]
# Dropping the 'CarName' & 'Car_ID' column as they are not useful for analysis

# %%
car.drop(['CarName', 'car_ID'],axis=1,inplace=True)

# %% [markdown]
# After extracting CarCompany from the CarName, we can see that there are few discrepancies in the CarCompany name. We will replace wrong name with the correct one.

# %%
car['CarCompany'].value_counts()
# Out:
# toyota         31
# nissan         18
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# volkswagen      9
# buick           8
# bmw             8
# plymouth        7
# audi            7
# saab            6
# porsche         4
# isuzu           4
# alfa-romero     3
# jaguar          3
# chevrolet       3
# renault         2
# maxda           2
# vw              2
# porcshce        1
# mercury         1
# toyouta         1
# vokswagen       1
# Name: CarCompany, dtype: int64

# %%
car['CarCompany'] = car['CarCompany'].str.replace('vw','volkswagen') 
car['CarCompany'] = car['CarCompany'].str.replace('vokswagen','volkswagen') 
car['CarCompany'] = car['CarCompany'].str.replace('toyouta','toyota') 
car['CarCompany'] = car['CarCompany'].str.replace('porcshce','porsche') 
car['CarCompany'] = car['CarCompany'].str.replace('maxda','mazda')

# %% [markdown]
# There are few discrepancies in the Fuelsystem and enginetype too. For example mfi is actually mpfi (Both acrym are same - (Multiple port fuel injection) and spdi should be spfi (Single port fuel injection). we will correct it.

# %%
car['fuelsystem'].value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
car['enginetype'].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# l         12
# dohc      12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
car["fuelsystem"]=car["fuelsystem"].str.replace('mfi', 'mpfi')
car["fuelsystem"]=car["fuelsystem"].str.replace('spdi', 'spfi')
car["enginetype"]=car["enginetype"].str.replace('dohcv', 'dohc')

# %% [markdown]
# ## Step 3: Data Preparation

# %% [markdown]
# ### Dealing with Categorical Fields
#
# #### We will  Generate dummy values for all 10 categorical variables.
#
# Note : We will generate dummy for variables which has 2 level instead for assigning binary values for the ease of understanding.

# %%
car = pd.get_dummies(car, columns =['fuelsystem','doornumber','cylindernumber','fueltype','aspiration','carbody','drivewheel','enginelocation','enginetype', 'CarCompany'], drop_first = True)

# %%
car.shape
# Out:
# (205, 62)

# %%
car.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#              ...         CarCompany_nissan  CarCompany_peugeot  \
# count        ...                205.000000          205.000000
# mean         ...                  0.087805            0.053659
# std          ...                  0.283704            0.225894
# min          ...                  0.000000            0.000000
# 25%          ...                  0.000000            0.000000
# 50%          ...                  0.000000            0.000000
# 75%          ...                  0.000000            0.000000
# max          ...                  1.000000            1.000000
#
#        CarCompany_plymouth  CarCompany_porsche  CarCompany_renault  \
# count           205.000000          205.000000          205.000000
# mean              0.034146            0.024390            0.009756
# std               0.182050            0.154635            0.098531
# min               0.000000            0.000000            0.000000
# 25%               0.000000            0.000000            0.000000
# 50%               0.000000            0.000000            0.000000
# 75%               0.000000            0.000000            0.000000
# max               1.000000            1.000000            1.000000
#
#        CarCompany_saab  CarCompany_subaru  CarCompany_toyota  \
# count       205.000000         205.000000         205.000000
# mean          0.029268           0.058537           0.156098
# std           0.168970           0.235330           0.363836
# min           0.000000           0.000000           0.000000
# 25%           0.000000           0.000000           0.000000
# 50%           0.000000           0.000000           0.000000
# 75%           0.000000           0.000000           0.000000
# max           1.000000           1.000000           1.000000
#
#        CarCompany_volkswagen  CarCompany_volvo
# count             205.000000        205.000000
# mean                0.058537          0.053659
# std                 0.235330          0.225894
# min                 0.000000          0.000000
# 25%                 0.000000          0.000000
# 50%                 0.000000          0.000000
# 75%                 0.000000          0.000000
# max                 1.000000          1.000000
#
# [8 rows x 62 columns]

# %% [markdown]
# ## Step 4: Splitting the Data into Training and Testing Sets
#
# As you know, the first basic step for regression is performing a train-test split.

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively

car_train, car_test = train_test_split(car, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# We will use MinMax scaling for rescaling the variables so that they have a comparable scale.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# Apply scaler() to all the columns except the 'dummy' variables
num_vars = ['symboling', 'wheelbase', 'carlength', 'carwidth','carheight','curbweight', 'enginesize','boreratio','stroke','compressionratio','horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']

car_train[num_vars] = scaler.fit_transform(car_train[num_vars])

# %%
car_train.head()
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 122        0.6   0.244828   0.426016  0.291667   0.265487    0.272692
# 125        1.0   0.272414   0.452033  0.666667   0.212389    0.500388
# 166        0.6   0.272414   0.448780  0.308333   0.424779    0.314973
# 1          1.0   0.068966   0.450407  0.316667   0.088496    0.411171
# 199        0.2   0.610345   0.775610  0.575000   0.858407    0.647401
#
#      enginesize  boreratio    stroke  compressionratio        ...         \
# 122    0.139623   0.230159  0.525253           0.15000        ...
# 125    0.339623   1.000000  0.464646           0.15625        ...
# 166    0.139623   0.444444  0.449495           0.15000        ...
# 1      0.260377   0.626984  0.247475           0.12500        ...
# 199    0.260377   0.746032  0.484848           0.03125        ...
#
#      CarCompany_nissan  CarCompany_peugeot  CarCompany_plymouth  \
# 122                  0                   0                    1
# 125                  0                   0                    0
# 166                  0                   0                    0
# 1                    0                   0                    0
# 199                  0                   0                    0
#
#      CarCompany_porsche  CarCompany_renault  CarCompany_saab  \
# 122                   0                   0                0
# 125                   1                   0                0
# 166                   0                   0                0
# 1                     0                   0                0
# 199                   0                   0                0
#
#      CarCompany_subaru  CarCompany_toyota  CarCompany_volkswagen  \
# 122                  0                  0                      0
# 125                  0                  0                      0
# 166                  0                  1                      0
# 1                    0                  0                      0
# 199                  0                  0                      0
#
#      CarCompany_volvo
# 122                 0
# 125                 0
# 166                 0
# 1                   0
# 199                 1
#
# [5 rows x 62 columns]

# %%
car_train.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  curbweight  \
# count  143.000000  143.000000  143.000000  143.000000  143.000000  143.000000
# mean     0.559441    0.411141    0.525476    0.461655    0.509004    0.407878
# std      0.239200    0.205581    0.204848    0.184517    0.215378    0.211269
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.400000    0.272414    0.399187    0.304167    0.353982    0.245539
# 50%      0.600000    0.341379    0.502439    0.425000    0.522124    0.355702
# 75%      0.600000    0.503448    0.669919    0.550000    0.668142    0.559542
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        enginesize   boreratio      stroke  compressionratio        ...         \
# count  143.000000  143.000000  143.000000        143.000000        ...
# mean     0.241351    0.497946    0.535389          0.190787        ...
# std      0.154619    0.207140    0.157843          0.237181        ...
# min      0.000000    0.000000    0.000000          0.000000        ...
# 25%      0.135849    0.305556    0.464646          0.100000        ...
# 50%      0.184906    0.500000    0.545455          0.125000        ...
# 75%      0.301887    0.682540    0.611111          0.150000        ...
# max      1.000000    1.000000    1.000000          1.000000        ...
#
#        CarCompany_nissan  CarCompany_peugeot  CarCompany_plymouth  \
# count         143.000000          143.000000           143.000000
# mean            0.097902            0.055944             0.027972
# std             0.298227            0.230621             0.165472
# min             0.000000            0.000000             0.000000
# 25%             0.000000            0.000000             0.000000
# 50%             0.000000            0.000000             0.000000
# 75%             0.000000            0.000000             0.000000
# max             1.000000            1.000000             1.000000
#
#        CarCompany_porsche  CarCompany_renault  CarCompany_saab  \
# count          143.000000          143.000000       143.000000
# mean             0.020979            0.013986         0.020979
# std              0.143818            0.117845         0.143818
# min              0.000000            0.000000         0.000000
# 25%              0.000000            0.000000         0.000000
# 50%              0.000000            0.000000         0.000000
# 75%              0.000000            0.000000         0.000000
# max              1.000000            1.000000         1.000000
#
#        CarCompany_subaru  CarCompany_toyota  CarCompany_volkswagen  \
# count         143.000000         143.000000             143.000000
# mean            0.076923           0.139860               0.048951
# std             0.267406           0.348061               0.216524
# min             0.000000           0.000000               0.000000
# 25%             0.000000           0.000000               0.000000
# 50%             0.000000           0.000000               0.000000
# 75%             0.000000           0.000000               0.000000
# max             1.000000           1.000000               1.000000
#
#        CarCompany_volvo
# count        143.000000
# mean           0.041958
# std            0.201198
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000
#
# [8 rows x 62 columns]

# %% [markdown]
# ### Dividing into X and Y sets for the model building

# %%
y_train = car_train.pop('price')
X_train = car_train

# %% [markdown]
# ## Step 5: Building a linear model
#
# we will be using the **LinearRegression function from SciKit Learn** for its compatibility with RFE (which is a utility from sklearn)

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 30
lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm, 30)             

# running RFE
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('symboling', False, 23),
#  ('wheelbase', True, 1),
#  ('carlength', True, 1),
#  ('carwidth', True, 1),
#  ('carheight', True, 1),
#  ('curbweight', True, 1),
#  ('enginesize', True, 1),
#  ('boreratio', True, 1),
#  ('stroke', True, 1),
#  ('compressionratio', False, 5),
#  ('horsepower', False, 26),
#  ('peakrpm', True, 1),
#  ('citympg', False, 13),
#  ('highwaympg', True, 1),
#  ('fuelsystem_2bbl', False, 24),
#  ('fuelsystem_4bbl', False, 12),
#  ('fuelsystem_idi', False, 4),
#  ('fuelsystem_mpfi', False, 14),
#  ('fuelsystem_spfi', False, 10),
#  ('doornumber_two', False, 21),
#  ('cylindernumber_five', True, 1),
#  ('cylindernumber_four', True, 1),
#  ('cylindernumber_six', False, 27),
#  ('cylindernumber_three', True, 1),
#  ('cylindernumber_twelve', True, 1),
#  ('cylindernumber_two', True, 1),
#  ('fueltype_gas', False, 3),
#  ('aspiration_turbo', True, 1),
#  ('carbody_hardtop', False, 7),
#  ('carbody_hatchback', False, 6),
#  ('carbody_sedan', False, 8),
#  ('carbody_wagon', False, 9),
#  ('drivewheel_fwd', False, 25),
#  ('drivewheel_rwd', False, 17),
#  ('enginelocation_rear', True, 1),
#  ('enginetype_l', True, 1),
#  ('enginetype_ohc', False, 19),
#  ('enginetype_ohcf', True, 1),
#  ('enginetype_ohcv', False, 15),
#  ('enginetype_rotor', True, 1),
#  ('CarCompany_audi', False, 18),
#  ('CarCompany_bmw', True, 1),
#  ('CarCompany_buick', False, 28),
#  ('CarCompany_chevrolet', False, 2),
#  ('CarCompany_dodge', True, 1),
#  ('CarCompany_honda', True, 1),
#  ('CarCompany_isuzu', False, 20),
#  ('CarCompany_jaguar', False, 11),
#  ('CarCompany_mazda', False, 30),
#  ('CarCompany_mercury', False, 32),
#  ('CarCompany_mitsubishi', True, 1),
#  ('CarCompany_nissan', False, 31),
#  ('CarCompany_peugeot', True, 1),
#  ('CarCompany_plymouth', True, 1),
#  ('CarCompany_porsche', True, 1),
#  ('CarCompany_renault', False, 16),
#  ('CarCompany_saab', True, 1),
#  ('CarCompany_subaru', True, 1),
#  ('CarCompany_toyota', False, 22),
#  ('CarCompany_volkswagen', False, 29),
#  ('CarCompany_volvo', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'stroke', 'peakrpm', 'highwaympg',
#        'cylindernumber_five', 'cylindernumber_four', 'cylindernumber_three',
#        'cylindernumber_twelve', 'cylindernumber_two', 'aspiration_turbo',
#        'enginelocation_rear', 'enginetype_l', 'enginetype_ohcf',
#        'enginetype_rotor', 'CarCompany_bmw', 'CarCompany_dodge',
#        'CarCompany_honda', 'CarCompany_mitsubishi', 'CarCompany_peugeot',
#        'CarCompany_plymouth', 'CarCompany_porsche', 'CarCompany_saab',
#        'CarCompany_subaru', 'CarCompany_volvo'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['symboling', 'compressionratio', 'horsepower', 'citympg',
#        'fuelsystem_2bbl', 'fuelsystem_4bbl', 'fuelsystem_idi',
#        'fuelsystem_mpfi', 'fuelsystem_spfi', 'doornumber_two',
#        'cylindernumber_six', 'fueltype_gas', 'carbody_hardtop',
#        'carbody_hatchback', 'carbody_sedan', 'carbody_wagon', 'drivewheel_fwd',
#        'drivewheel_rwd', 'enginetype_ohc', 'enginetype_ohcv',
#        'CarCompany_audi', 'CarCompany_buick', 'CarCompany_chevrolet',
#        'CarCompany_isuzu', 'CarCompany_jaguar', 'CarCompany_mazda',
#        'CarCompany_mercury', 'CarCompany_nissan', 'CarCompany_renault',
#        'CarCompany_toyota', 'CarCompany_volkswagen'],
#       dtype='object')

# %% [markdown]
# ### Building model using statsmodel, for the detailed statistics

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     114.9
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           9.20e-71
# Time:                        00:19:33   Log-Likelihood:                 255.17
# No. Observations:                 143   AIC:                            -454.3
# Df Residuals:                     115   BIC:                            -371.4
# Df Model:                          27
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.3669      0.055     -6.712      0.000      -0.475      -0.259
# wheelbase                 0.1129      0.058      1.963      0.052      -0.001       0.227
# carlength                -0.0774      0.073     -1.056      0.293      -0.223       0.068
# carwidth                  0.2501      0.066      3.811      0.000       0.120       0.380
# carheight                -0.0819      0.034     -2.421      0.017      -0.149      -0.015
# curbweight                0.3233      0.090      3.584      0.000       0.145       0.502
# enginesize                1.7218      0.176      9.809      0.000       1.374       2.069
# boreratio                -0.5296      0.069     -7.705      0.000      -0.666      -0.393
# stroke                   -0.2534      0.046     -5.489      0.000      -0.345      -0.162
# peakrpm                   0.1100      0.031      3.538      0.001       0.048       0.172
# highwaympg                0.0768      0.045      1.702      0.091      -0.013       0.166
# cylindernumber_five       0.2144      0.031      6.877      0.000       0.153       0.276
# cylindernumber_four       0.3147      0.037      8.411      0.000       0.241       0.389
# cylindernumber_three      0.3491      0.045      7.726      0.000       0.260       0.439
# cylindernumber_twelve    -0.6251      0.088     -7.138      0.000      -0.799      -0.452
# cylindernumber_two        0.3052      0.035      8.781      0.000       0.236       0.374
# aspiration_turbo          0.0671      0.015      4.441      0.000       0.037       0.097
# enginelocation_rear       0.1868      0.047      4.008      0.000       0.094       0.279
# enginetype_l              0.1376      0.025      5.538      0.000       0.088       0.187
# enginetype_ohcf           0.1261      0.024      5.346      0.000       0.079       0.173
# enginetype_rotor          0.3052      0.035      8.781      0.000       0.236       0.374
# CarCompany_bmw            0.3303      0.025     13.313      0.000       0.281       0.379
# CarCompany_dodge         -0.0802      0.024     -3.348      0.001      -0.128      -0.033
# CarCompany_honda         -0.0586      0.022     -2.696      0.008      -0.102      -0.016
# CarCompany_mitsubishi    -0.1139      0.020     -5.656      0.000      -0.154      -0.074
# CarCompany_peugeot       -0.2115      0.028     -7.434      0.000      -0.268      -0.155
# CarCompany_plymouth      -0.0826      0.027     -3.062      0.003      -0.136      -0.029
# CarCompany_porsche        0.2241      0.050      4.508      0.000       0.126       0.323
# CarCompany_saab           0.1023      0.032      3.201      0.002       0.039       0.166
# CarCompany_subaru        -0.0607      0.031     -1.956      0.053      -0.122       0.001
# CarCompany_volvo          0.0843      0.028      2.977      0.004       0.028       0.140
# ==============================================================================
# Omnibus:                       35.760   Durbin-Watson:                   1.737
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              131.829
# Skew:                           0.839   Prob(JB):                     2.36e-29
# Kurtosis:                       7.395   Cond. No.                     1.19e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.71e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Checking VIF
#
# Variance Inflation Factor or VIF, gives a basic quantitative idea about how much the feature variables are correlated with each other. It is an extremely important parameter to test our linear model. The formula for calculating `VIF` is:
#
# ### $ VIF_i = \frac{1}{1 - {R_i}^2} $

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_rfe
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features         VIF
# 15     cylindernumber_two         inf
# 13   cylindernumber_three         inf
# 29      CarCompany_subaru         inf
# 25     CarCompany_peugeot         inf
# 20       enginetype_rotor         inf
# 19        enginetype_ohcf         inf
# 18           enginetype_l         inf
# 17    enginelocation_rear         inf
# 0                   const  208.160000
# 6              enginesize   50.960000
# 5              curbweight   25.120000
# 12    cylindernumber_four   18.700000
# 2               carlength   15.600000
# 7               boreratio   14.020000
# 3                carwidth   10.140000
# 1               wheelbase    9.690000
# 10             highwaympg    5.000000
# 11    cylindernumber_five    3.990000
# 14  cylindernumber_twelve    3.710000
# 4               carheight    3.670000
# 8                  stroke    3.670000
# 27     CarCompany_porsche    3.540000
# 9                 peakrpm    2.580000
# 16       aspiration_turbo    2.370000
# 30       CarCompany_volvo    2.250000
# 23       CarCompany_honda    1.940000
# 21         CarCompany_bmw    1.720000
# 24  CarCompany_mitsubishi    1.670000
# 22       CarCompany_dodge    1.610000
# 28        CarCompany_saab    1.460000
# 26    CarCompany_plymouth    1.380000

# %% [markdown]
# Since `cylindernumber_two` is insignificant (vif value inf) in presence of other variables; can be dropped

# %%
X_train_new = X_train_rfe.drop(["carlength"], axis = 1)

# %% [markdown]
# Rebuilding the model without `cylindernumber_two`

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     119.2
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           1.44e-71
# Time:                        00:19:33   Log-Likelihood:                 254.48
# No. Observations:                 143   AIC:                            -455.0
# Df Residuals:                     116   BIC:                            -375.0
# Df Model:                          26
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.3784      0.054     -7.063      0.000      -0.485      -0.272
# wheelbase                 0.0890      0.053      1.682      0.095      -0.016       0.194
# carwidth                  0.2229      0.060      3.691      0.000       0.103       0.343
# carheight                -0.0838      0.034     -2.480      0.015      -0.151      -0.017
# curbweight                0.2865      0.083      3.442      0.001       0.122       0.451
# enginesize                1.7818      0.166     10.724      0.000       1.453       2.111
# boreratio                -0.5514      0.066     -8.403      0.000      -0.681      -0.421
# stroke                   -0.2639      0.045     -5.851      0.000      -0.353      -0.175
# peakrpm                   0.1092      0.031      3.512      0.001       0.048       0.171
# highwaympg                0.0865      0.044      1.958      0.053      -0.001       0.174
# cylindernumber_five       0.2213      0.031      7.252      0.000       0.161       0.282
# cylindernumber_four       0.3207      0.037      8.671      0.000       0.247       0.394
# cylindernumber_three      0.3563      0.045      7.972      0.000       0.268       0.445
# cylindernumber_twelve    -0.6480      0.085     -7.632      0.000      -0.816      -0.480
# cylindernumber_two        0.3165      0.033      9.566      0.000       0.251       0.382
# aspiration_turbo          0.0722      0.014      5.038      0.000       0.044       0.101
# enginelocation_rear       0.1703      0.044      3.877      0.000       0.083       0.257
# enginetype_l              0.1437      0.024      5.937      0.000       0.096       0.192
# enginetype_ohcf           0.1202      0.023      5.243      0.000       0.075       0.166
# enginetype_rotor          0.3165      0.033      9.566      0.000       0.251       0.382
# CarCompany_bmw            0.3281      0.025     13.265      0.000       0.279       0.377
# CarCompany_dodge         -0.0756      0.024     -3.209      0.002      -0.122      -0.029
# CarCompany_honda         -0.0521      0.021     -2.498      0.014      -0.093      -0.011
# CarCompany_mitsubishi    -0.1128      0.020     -5.606      0.000      -0.153      -0.073
# CarCompany_peugeot       -0.2127      0.028     -7.477      0.000      -0.269      -0.156
# CarCompany_plymouth      -0.0835      0.027     -3.097      0.002      -0.137      -0.030
# CarCompany_porsche        0.2452      0.046      5.385      0.000       0.155       0.335
# CarCompany_saab           0.0962      0.031      3.059      0.003       0.034       0.159
# CarCompany_subaru        -0.0501      0.029     -1.705      0.091      -0.108       0.008
# CarCompany_volvo          0.0869      0.028      3.079      0.003       0.031       0.143
# ==============================================================================
# Omnibus:                       34.152   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.946
# Skew:                           0.825   Prob(JB):                     6.65e-26
# Kurtosis:                       7.091   Cond. No.                     1.21e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.32e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features         VIF
# 24     CarCompany_peugeot         inf
# 28      CarCompany_subaru         inf
# 19       enginetype_rotor         inf
# 18        enginetype_ohcf         inf
# 17           enginetype_l         inf
# 16    enginelocation_rear         inf
# 14     cylindernumber_two         inf
# 12   cylindernumber_three         inf
# 0                   const  199.820000
# 5              enginesize   45.610000
# 4              curbweight   21.380000
# 11    cylindernumber_four   18.260000
# 6               boreratio   12.770000
# 2                carwidth    8.580000
# 1               wheelbase    8.180000
# 9              highwaympg    4.790000
# 10    cylindernumber_five    3.820000
# 3               carheight    3.660000
# 7                  stroke    3.500000
# 13  cylindernumber_twelve    3.480000
# 26     CarCompany_porsche    2.960000
# 8                 peakrpm    2.580000
# 29       CarCompany_volvo    2.230000
# 15       aspiration_turbo    2.130000
# 22       CarCompany_honda    1.780000
# 20         CarCompany_bmw    1.710000
# 23  CarCompany_mitsubishi    1.660000
# 21       CarCompany_dodge    1.550000
# 27        CarCompany_saab    1.410000
# 25    CarCompany_plymouth    1.380000

# %% [markdown]
# Since `cylindernumber_twelve` is insignificant (P value 0.112) in presence of other variables; can be dropped

# %%
X_train_new = X_train_new.drop(["CarCompany_subaru"], axis = 1)

# %% [markdown]
# Rebuilding the model without `cylindernumber_twelve`

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     119.2
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           1.44e-71
# Time:                        00:19:34   Log-Likelihood:                 254.48
# No. Observations:                 143   AIC:                            -455.0
# Df Residuals:                     116   BIC:                            -375.0
# Df Model:                          26
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.3784      0.054     -7.063      0.000      -0.485      -0.272
# wheelbase                 0.0890      0.053      1.682      0.095      -0.016       0.194
# carwidth                  0.2229      0.060      3.691      0.000       0.103       0.343
# carheight                -0.0838      0.034     -2.480      0.015      -0.151      -0.017
# curbweight                0.2865      0.083      3.442      0.001       0.122       0.451
# enginesize                1.7818      0.166     10.724      0.000       1.453       2.111
# boreratio                -0.5514      0.066     -8.403      0.000      -0.681      -0.421
# stroke                   -0.2639      0.045     -5.851      0.000      -0.353      -0.175
# peakrpm                   0.1092      0.031      3.512      0.001       0.048       0.171
# highwaympg                0.0865      0.044      1.958      0.053      -0.001       0.174
# cylindernumber_five       0.2213      0.031      7.252      0.000       0.161       0.282
# cylindernumber_four       0.3207      0.037      8.671      0.000       0.247       0.394
# cylindernumber_three      0.3563      0.045      7.972      0.000       0.268       0.445
# cylindernumber_twelve    -0.6480      0.085     -7.632      0.000      -0.816      -0.480
# cylindernumber_two        0.3165      0.033      9.566      0.000       0.251       0.382
# aspiration_turbo          0.0722      0.014      5.038      0.000       0.044       0.101
# enginelocation_rear       0.2203      0.071      3.099      0.002       0.079       0.361
# enginetype_l              0.1437      0.024      5.937      0.000       0.096       0.192
# enginetype_ohcf           0.0701      0.029      2.410      0.018       0.012       0.128
# enginetype_rotor          0.3165      0.033      9.566      0.000       0.251       0.382
# CarCompany_bmw            0.3281      0.025     13.265      0.000       0.279       0.377
# CarCompany_dodge         -0.0756      0.024     -3.209      0.002      -0.122      -0.029
# CarCompany_honda         -0.0521      0.021     -2.498      0.014      -0.093      -0.011
# CarCompany_mitsubishi    -0.1128      0.020     -5.606      0.000      -0.153      -0.073
# CarCompany_peugeot       -0.2127      0.028     -7.477      0.000      -0.269      -0.156
# CarCompany_plymouth      -0.0835      0.027     -3.097      0.002      -0.137      -0.030
# CarCompany_porsche        0.2452      0.046      5.385      0.000       0.155       0.335
# CarCompany_saab           0.0962      0.031      3.059      0.003       0.034       0.159
# CarCompany_volvo          0.0869      0.028      3.079      0.003       0.031       0.143
# ==============================================================================
# Omnibus:                       34.152   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.946
# Skew:                           0.825   Prob(JB):                     6.65e-26
# Kurtosis:                       7.091   Cond. No.                     1.21e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.31e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features         VIF
# 14     cylindernumber_two         inf
# 12   cylindernumber_three         inf
# 24     CarCompany_peugeot         inf
# 19       enginetype_rotor         inf
# 17           enginetype_l         inf
# 0                   const  199.820000
# 5              enginesize   45.610000
# 4              curbweight   21.380000
# 11    cylindernumber_four   18.260000
# 6               boreratio   12.770000
# 2                carwidth    8.580000
# 1               wheelbase    8.180000
# 9              highwaympg    4.790000
# 18        enginetype_ohcf    4.530000
# 10    cylindernumber_five    3.820000
# 3               carheight    3.660000
# 7                  stroke    3.500000
# 13  cylindernumber_twelve    3.480000
# 26     CarCompany_porsche    2.960000
# 8                 peakrpm    2.580000
# 16    enginelocation_rear    2.440000
# 28       CarCompany_volvo    2.230000
# 15       aspiration_turbo    2.130000
# 22       CarCompany_honda    1.780000
# 20         CarCompany_bmw    1.710000
# 23  CarCompany_mitsubishi    1.660000
# 21       CarCompany_dodge    1.550000
# 27        CarCompany_saab    1.410000
# 25    CarCompany_plymouth    1.380000

# %% [markdown]
# Now that we have p value of all variables under 0.05, we will look for VIF value. We generally want a VIF that is less than 5.

# %% [markdown]
# Since `curbweight` is insignificant (VIP value 8.64) in presence of other variables; can be dropped

# %%
X_train_new = X_train_new.drop(["wheelbase"], axis = 1)

# %% [markdown]
# Rebuilding the model without `curbweight`

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     121.9
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           5.16e-72
# Time:                        00:19:35   Log-Likelihood:                 252.75
# No. Observations:                 143   AIC:                            -453.5
# Df Residuals:                     117   BIC:                            -376.5
# Df Model:                          25
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.3936      0.053     -7.396      0.000      -0.499      -0.288
# carwidth                  0.2699      0.054      5.002      0.000       0.163       0.377
# carheight                -0.0614      0.031     -1.963      0.052      -0.123       0.001
# curbweight                0.3136      0.082      3.811      0.000       0.151       0.477
# enginesize                1.7828      0.167     10.647      0.000       1.451       2.114
# boreratio                -0.5558      0.066     -8.412      0.000      -0.687      -0.425
# stroke                   -0.2507      0.045     -5.601      0.000      -0.339      -0.162
# peakrpm                   0.1068      0.031      3.411      0.001       0.045       0.169
# highwaympg                0.0886      0.044      1.992      0.049       0.001       0.177
# cylindernumber_five       0.2237      0.031      7.282      0.000       0.163       0.284
# cylindernumber_four       0.3223      0.037      8.650      0.000       0.249       0.396
# cylindernumber_three      0.3533      0.045      7.850      0.000       0.264       0.442
# cylindernumber_twelve    -0.6527      0.086     -7.633      0.000      -0.822      -0.483
# cylindernumber_two        0.3186      0.033      9.560      0.000       0.253       0.385
# aspiration_turbo          0.0666      0.014      4.739      0.000       0.039       0.094
# enginelocation_rear       0.2163      0.072      3.021      0.003       0.074       0.358
# enginetype_l              0.1507      0.024      6.278      0.000       0.103       0.198
# enginetype_ohcf           0.0763      0.029      2.621      0.010       0.019       0.134
# enginetype_rotor          0.3186      0.033      9.560      0.000       0.253       0.385
# CarCompany_bmw            0.3362      0.024     13.748      0.000       0.288       0.385
# CarCompany_dodge         -0.0693      0.023     -2.956      0.004      -0.116      -0.023
# CarCompany_honda         -0.0547      0.021     -2.609      0.010      -0.096      -0.013
# CarCompany_mitsubishi    -0.1105      0.020     -5.461      0.000      -0.151      -0.070
# CarCompany_peugeot       -0.2026      0.028     -7.230      0.000      -0.258      -0.147
# CarCompany_plymouth      -0.0784      0.027     -2.903      0.004      -0.132      -0.025
# CarCompany_porsche        0.2276      0.045      5.097      0.000       0.139       0.316
# CarCompany_saab           0.0935      0.032      2.955      0.004       0.031       0.156
# CarCompany_volvo          0.0996      0.027      3.630      0.000       0.045       0.154
# ==============================================================================
# Omnibus:                       32.477   Durbin-Watson:                   1.766
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.750
# Skew:                           0.808   Prob(JB):                     8.04e-23
# Kurtosis:                       6.803   Cond. No.                     1.22e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.07e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features         VIF
# 23     CarCompany_peugeot         inf
# 18       enginetype_rotor         inf
# 16           enginetype_l         inf
# 13     cylindernumber_two         inf
# 11   cylindernumber_three         inf
# 0                   const  194.140000
# 4              enginesize   45.610000
# 3              curbweight   20.570000
# 10    cylindernumber_four   18.250000
# 5               boreratio   12.750000
# 1                carwidth    6.740000
# 8              highwaympg    4.790000
# 17        enginetype_ohcf    4.460000
# 9     cylindernumber_five    3.810000
# 12  cylindernumber_twelve    3.480000
# 6                  stroke    3.400000
# 2               carheight    3.090000
# 25     CarCompany_porsche    2.810000
# 7                 peakrpm    2.570000
# 15    enginelocation_rear    2.440000
# 27       CarCompany_volvo    2.070000
# 14       aspiration_turbo    2.010000
# 21       CarCompany_honda    1.770000
# 22  CarCompany_mitsubishi    1.660000
# 19         CarCompany_bmw    1.650000
# 20       CarCompany_dodge    1.510000
# 26        CarCompany_saab    1.410000
# 24    CarCompany_plymouth    1.360000

# %% [markdown]
# Since `carwidth` is insignificant (VIF value 3.16) in presence of other variables; can be dropped

# %%
X_train_new = X_train_new.drop(["carheight"], axis = 1)

# %% [markdown]
# Rebuilding the model without `carwidth`

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     123.9
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           3.00e-72
# Time:                        00:19:36   Log-Likelihood:                 250.44
# No. Observations:                 143   AIC:                            -450.9
# Df Residuals:                     118   BIC:                            -376.8
# Df Model:                          24
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4185      0.052     -7.999      0.000      -0.522      -0.315
# carwidth                  0.2605      0.054      4.789      0.000       0.153       0.368
# curbweight                0.2520      0.077      3.273      0.001       0.100       0.404
# enginesize                1.8733      0.163     11.499      0.000       1.551       2.196
# boreratio                -0.5432      0.067     -8.162      0.000      -0.675      -0.411
# stroke                   -0.2668      0.045     -5.990      0.000      -0.355      -0.179
# peakrpm                   0.1172      0.031      3.751      0.000       0.055       0.179
# highwaympg                0.0893      0.045      1.984      0.050       0.000       0.178
# cylindernumber_five       0.2198      0.031      7.086      0.000       0.158       0.281
# cylindernumber_four       0.3191      0.038      8.469      0.000       0.244       0.394
# cylindernumber_three      0.3527      0.046      7.742      0.000       0.262       0.443
# cylindernumber_twelve    -0.6589      0.086     -7.619      0.000      -0.830      -0.488
# cylindernumber_two        0.3344      0.033     10.221      0.000       0.270       0.399
# aspiration_turbo          0.0725      0.014      5.218      0.000       0.045       0.100
# enginelocation_rear       0.1949      0.072      2.720      0.008       0.053       0.337
# enginetype_l              0.1467      0.024      6.061      0.000       0.099       0.195
# enginetype_ohcf           0.0710      0.029      2.420      0.017       0.013       0.129
# enginetype_rotor          0.3344      0.033     10.221      0.000       0.270       0.399
# CarCompany_bmw            0.3242      0.024     13.528      0.000       0.277       0.372
# CarCompany_dodge         -0.0549      0.023     -2.437      0.016      -0.100      -0.010
# CarCompany_honda         -0.0526      0.021     -2.481      0.015      -0.094      -0.011
# CarCompany_mitsubishi    -0.0962      0.019     -5.036      0.000      -0.134      -0.058
# CarCompany_peugeot       -0.2059      0.028     -7.276      0.000      -0.262      -0.150
# CarCompany_plymouth      -0.0628      0.026     -2.404      0.018      -0.114      -0.011
# CarCompany_porsche        0.2349      0.045      5.214      0.000       0.146       0.324
# CarCompany_saab           0.0826      0.032      2.619      0.010       0.020       0.145
# CarCompany_volvo          0.0872      0.027      3.227      0.002       0.034       0.141
# ==============================================================================
# Omnibus:                       31.404   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               97.377
# Skew:                           0.781   Prob(JB):                     7.16e-22
# Kurtosis:                       6.729   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.7e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features         VIF
# 22     CarCompany_peugeot         inf
# 17       enginetype_rotor         inf
# 15           enginetype_l         inf
# 12     cylindernumber_two         inf
# 10   cylindernumber_three         inf
# 0                   const  183.140000
# 3              enginesize   42.160000
# 9     cylindernumber_four   18.220000
# 2              curbweight   17.580000
# 4               boreratio   12.630000
# 1                carwidth    6.690000
# 7              highwaympg    4.780000
# 16        enginetype_ohcf    4.420000
# 8     cylindernumber_five    3.800000
# 11  cylindernumber_twelve    3.480000
# 5                  stroke    3.280000
# 24     CarCompany_porsche    2.790000
# 6                 peakrpm    2.500000
# 14    enginelocation_rear    2.380000
# 26       CarCompany_volvo    1.960000
# 13       aspiration_turbo    1.920000
# 20       CarCompany_honda    1.770000
# 18         CarCompany_bmw    1.550000
# 21  CarCompany_mitsubishi    1.440000
# 19       CarCompany_dodge    1.370000
# 25        CarCompany_saab    1.370000
# 23    CarCompany_plymouth    1.240000

# %% [markdown]
# Since `boreratio` is insignificant (p value 0.727) in presence of other variables; can be dropped

# %%
X_train_new = X_train_new.drop(["CarCompany_peugeot"], axis = 1)

# %% [markdown]
# Rebuilding the model without `boreratio`

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     123.9
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           3.00e-72
# Time:                        00:19:36   Log-Likelihood:                 250.44
# No. Observations:                 143   AIC:                            -450.9
# Df Residuals:                     118   BIC:                            -376.8
# Df Model:                          24
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4185      0.052     -7.999      0.000      -0.522      -0.315
# carwidth                  0.2605      0.054      4.789      0.000       0.153       0.368
# curbweight                0.2520      0.077      3.273      0.001       0.100       0.404
# enginesize                1.8733      0.163     11.499      0.000       1.551       2.196
# boreratio                -0.5432      0.067     -8.162      0.000      -0.675      -0.411
# stroke                   -0.2668      0.045     -5.990      0.000      -0.355      -0.179
# peakrpm                   0.1172      0.031      3.751      0.000       0.055       0.179
# highwaympg                0.0893      0.045      1.984      0.050       0.000       0.178
# cylindernumber_five       0.2198      0.031      7.086      0.000       0.158       0.281
# cylindernumber_four       0.3191      0.038      8.469      0.000       0.244       0.394
# cylindernumber_three      0.5586      0.072      7.772      0.000       0.416       0.701
# cylindernumber_twelve    -0.6589      0.086     -7.619      0.000      -0.830      -0.488
# cylindernumber_two        0.3344      0.033     10.221      0.000       0.270       0.399
# aspiration_turbo          0.0725      0.014      5.218      0.000       0.045       0.100
# enginelocation_rear       0.1949      0.072      2.720      0.008       0.053       0.337
# enginetype_l             -0.0592      0.026     -2.237      0.027      -0.112      -0.007
# enginetype_ohcf           0.0710      0.029      2.420      0.017       0.013       0.129
# enginetype_rotor          0.3344      0.033     10.221      0.000       0.270       0.399
# CarCompany_bmw            0.3242      0.024     13.528      0.000       0.277       0.372
# CarCompany_dodge         -0.0549      0.023     -2.437      0.016      -0.100      -0.010
# CarCompany_honda         -0.0526      0.021     -2.481      0.015      -0.094      -0.011
# CarCompany_mitsubishi    -0.0962      0.019     -5.036      0.000      -0.134      -0.058
# CarCompany_plymouth      -0.0628      0.026     -2.404      0.018      -0.114      -0.011
# CarCompany_porsche        0.2349      0.045      5.214      0.000       0.146       0.324
# CarCompany_saab           0.0826      0.032      2.619      0.010       0.020       0.145
# CarCompany_volvo          0.0872      0.027      3.227      0.002       0.034       0.141
# ==============================================================================
# Omnibus:                       31.404   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               97.377
# Skew:                           0.781   Prob(JB):                     7.16e-22
# Kurtosis:                       6.729   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.69e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features         VIF
# 17       enginetype_rotor         inf
# 12     cylindernumber_two         inf
# 0                   const  183.140000
# 3              enginesize   42.160000
# 9     cylindernumber_four   18.220000
# 2              curbweight   17.580000
# 4               boreratio   12.630000
# 1                carwidth    6.690000
# 7              highwaympg    4.780000
# 16        enginetype_ohcf    4.420000
# 8     cylindernumber_five    3.800000
# 11  cylindernumber_twelve    3.480000
# 5                  stroke    3.280000
# 23     CarCompany_porsche    2.790000
# 15           enginetype_l    2.760000
# 6                 peakrpm    2.500000
# 10   cylindernumber_three    2.400000
# 14    enginelocation_rear    2.380000
# 25       CarCompany_volvo    1.960000
# 13       aspiration_turbo    1.920000
# 20       CarCompany_honda    1.770000
# 18         CarCompany_bmw    1.550000
# 21  CarCompany_mitsubishi    1.440000
# 19       CarCompany_dodge    1.370000
# 24        CarCompany_saab    1.370000
# 22    CarCompany_plymouth    1.240000

# %% [markdown]
# Since `stroke` is insignificant (p value .649) in presence of other variables; can be dropped

# %%
X_train_new = X_train_new.drop(["enginetype_rotor"], axis = 1)

# %% [markdown]
# Rebuilding the model without `stroke`

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     123.9
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           3.00e-72
# Time:                        00:19:37   Log-Likelihood:                 250.44
# No. Observations:                 143   AIC:                            -450.9
# Df Residuals:                     118   BIC:                            -376.8
# Df Model:                          24
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.4185      0.052     -7.999      0.000      -0.522      -0.315
# carwidth                  0.2605      0.054      4.789      0.000       0.153       0.368
# curbweight                0.2520      0.077      3.273      0.001       0.100       0.404
# enginesize                1.8733      0.163     11.499      0.000       1.551       2.196
# boreratio                -0.5432      0.067     -8.162      0.000      -0.675      -0.411
# stroke                   -0.2668      0.045     -5.990      0.000      -0.355      -0.179
# peakrpm                   0.1172      0.031      3.751      0.000       0.055       0.179
# highwaympg                0.0893      0.045      1.984      0.050       0.000       0.178
# cylindernumber_five       0.2198      0.031      7.086      0.000       0.158       0.281
# cylindernumber_four       0.3191      0.038      8.469      0.000       0.244       0.394
# cylindernumber_three      0.5586      0.072      7.772      0.000       0.416       0.701
# cylindernumber_twelve    -0.6589      0.086     -7.619      0.000      -0.830      -0.488
# cylindernumber_two        0.6688      0.065     10.221      0.000       0.539       0.798
# aspiration_turbo          0.0725      0.014      5.218      0.000       0.045       0.100
# enginelocation_rear       0.1949      0.072      2.720      0.008       0.053       0.337
# enginetype_l             -0.0592      0.026     -2.237      0.027      -0.112      -0.007
# enginetype_ohcf           0.0710      0.029      2.420      0.017       0.013       0.129
# CarCompany_bmw            0.3242      0.024     13.528      0.000       0.277       0.372
# CarCompany_dodge         -0.0549      0.023     -2.437      0.016      -0.100      -0.010
# CarCompany_honda         -0.0526      0.021     -2.481      0.015      -0.094      -0.011
# CarCompany_mitsubishi    -0.0962      0.019     -5.036      0.000      -0.134      -0.058
# CarCompany_plymouth      -0.0628      0.026     -2.404      0.018      -0.114      -0.011
# CarCompany_porsche        0.2349      0.045      5.214      0.000       0.146       0.324
# CarCompany_saab           0.0826      0.032      2.619      0.010       0.020       0.145
# CarCompany_volvo          0.0872      0.027      3.227      0.002       0.034       0.141
# ==============================================================================
# Omnibus:                       31.404   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               97.377
# Skew:                           0.781   Prob(JB):                     7.16e-22
# Kurtosis:                       6.729   Cond. No.                         91.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features     VIF
# 0                   const  183.14
# 3              enginesize   42.16
# 9     cylindernumber_four   18.22
# 2              curbweight   17.58
# 4               boreratio   12.63
# 12     cylindernumber_two    7.79
# 1                carwidth    6.69
# 7              highwaympg    4.78
# 16        enginetype_ohcf    4.42
# 8     cylindernumber_five    3.80
# 11  cylindernumber_twelve    3.48
# 5                  stroke    3.28
# 22     CarCompany_porsche    2.79
# 15           enginetype_l    2.76
# 6                 peakrpm    2.50
# 10   cylindernumber_three    2.40
# 14    enginelocation_rear    2.38
# 24       CarCompany_volvo    1.96
# 13       aspiration_turbo    1.92
# 19       CarCompany_honda    1.77
# 17         CarCompany_bmw    1.55
# 20  CarCompany_mitsubishi    1.44
# 18       CarCompany_dodge    1.37
# 23        CarCompany_saab    1.37
# 21    CarCompany_plymouth    1.24

# %% [markdown]
# Since `cylindernumber_three` is insignificant (p value 0.338) in presence of other variables; can be dropped

# %%
X_train_new = X_train_new.drop(["enginesize"], axis = 1)

# %% [markdown]
# Rebuilding the model without `cylindernumber_three`

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     58.74
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           4.32e-54
# Time:                        00:19:38   Log-Likelihood:                 196.69
# No. Observations:                 143   AIC:                            -345.4
# Df Residuals:                     119   BIC:                            -274.3
# Df Model:                          23
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2275      0.072     -3.163      0.002      -0.370      -0.085
# carwidth                  0.3741      0.078      4.823      0.000       0.221       0.528
# curbweight                0.6503      0.100      6.522      0.000       0.453       0.848
# boreratio                 0.0083      0.067      0.125      0.901      -0.124       0.141
# stroke                   -0.0840      0.060     -1.392      0.167      -0.203       0.036
# peakrpm                   0.0665      0.045      1.482      0.141      -0.022       0.155
# highwaympg                0.1056      0.065      1.618      0.108      -0.024       0.235
# cylindernumber_five      -0.0307      0.032     -0.959      0.339      -0.094       0.033
# cylindernumber_four      -0.0254      0.033     -0.767      0.444      -0.091       0.040
# cylindernumber_three      0.3147      0.100      3.160      0.002       0.117       0.512
# cylindernumber_twelve     0.1340      0.076      1.769      0.079      -0.016       0.284
# cylindernumber_two        0.0181      0.048      0.381      0.704      -0.076       0.113
# aspiration_turbo          0.0387      0.020      1.964      0.052      -0.000       0.078
# enginelocation_rear       0.4878      0.097      5.025      0.000       0.296       0.680
# enginetype_l             -0.1806      0.035     -5.137      0.000      -0.250      -0.111
# enginetype_ohcf          -0.0613      0.039     -1.568      0.120      -0.139       0.016
# CarCompany_bmw            0.2540      0.034      7.557      0.000       0.187       0.321
# CarCompany_dodge          0.0038      0.032      0.118      0.906      -0.059       0.067
# CarCompany_honda          0.0011      0.030      0.035      0.972      -0.058       0.060
# CarCompany_mitsubishi    -0.0565      0.027     -2.075      0.040      -0.110      -0.003
# CarCompany_plymouth      -0.0040      0.037     -0.109      0.914      -0.078       0.069
# CarCompany_porsche        0.0861      0.063      1.376      0.171      -0.038       0.210
# CarCompany_saab          -0.0206      0.044     -0.470      0.639      -0.107       0.066
# CarCompany_volvo         -0.0448      0.035     -1.262      0.209      -0.115       0.025
# ==============================================================================
# Omnibus:                       21.706   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.945
# Skew:                           0.566   Prob(JB):                     1.17e-12
# Kurtosis:                       5.818   Cond. No.                         40.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features     VIF
# 0                   const  164.69
# 2              curbweight   14.02
# 8     cylindernumber_four    6.70
# 1                carwidth    6.47
# 3               boreratio    6.07
# 6              highwaympg    4.78
# 15        enginetype_ohcf    3.74
# 4                  stroke    2.87
# 21     CarCompany_porsche    2.56
# 5                 peakrpm    2.45
# 14           enginetype_l    2.32
# 9    cylindernumber_three    2.19
# 13    enginelocation_rear    2.08
# 11     cylindernumber_two    1.97
# 7     cylindernumber_five    1.92
# 12       aspiration_turbo    1.83
# 18       CarCompany_honda    1.68
# 23       CarCompany_volvo    1.61
# 16         CarCompany_bmw    1.44
# 19  CarCompany_mitsubishi    1.39
# 17       CarCompany_dodge    1.30
# 10  cylindernumber_twelve    1.27
# 22        CarCompany_saab    1.26
# 20    CarCompany_plymouth    1.19

# %% [markdown]
# Since `enginelocation_rear` is insignificant (p value 0.236) in presence of other variables; can be dropped

# %%
X_train_new = X_train_new.drop(["CarCompany_honda"], axis = 1)

# %% [markdown]
# Rebuilding the model without `enginelocation_rear`

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     61.92
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           5.41e-55
# Time:                        00:19:39   Log-Likelihood:                 196.69
# No. Observations:                 143   AIC:                            -347.4
# Df Residuals:                     120   BIC:                            -279.2
# Df Model:                          22
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2282      0.069     -3.302      0.001      -0.365      -0.091
# carwidth                  0.3742      0.077      4.853      0.000       0.222       0.527
# curbweight                0.6506      0.099      6.575      0.000       0.455       0.847
# boreratio                 0.0077      0.064      0.120      0.905      -0.119       0.134
# stroke                   -0.0832      0.056     -1.484      0.140      -0.194       0.028
# peakrpm                   0.0671      0.041      1.645      0.103      -0.014       0.148
# highwaympg                0.1057      0.065      1.630      0.106      -0.023       0.234
# cylindernumber_five      -0.0308      0.032     -0.967      0.336      -0.094       0.032
# cylindernumber_four      -0.0252      0.032     -0.776      0.439      -0.090       0.039
# cylindernumber_three      0.3147      0.099      3.173      0.002       0.118       0.511
# cylindernumber_twelve     0.1342      0.075      1.789      0.076      -0.014       0.283
# cylindernumber_two        0.0181      0.047      0.381      0.704      -0.076       0.112
# aspiration_turbo          0.0386      0.020      1.972      0.051      -0.000       0.077
# enginelocation_rear       0.4875      0.096      5.062      0.000       0.297       0.678
# enginetype_l             -0.1805      0.035     -5.169      0.000      -0.250      -0.111
# enginetype_ohcf          -0.0609      0.037     -1.642      0.103      -0.134       0.013
# CarCompany_bmw            0.2542      0.033      7.678      0.000       0.189       0.320
# CarCompany_dodge          0.0034      0.030      0.113      0.910      -0.057       0.064
# CarCompany_mitsubishi    -0.0568      0.026     -2.162      0.033      -0.109      -0.005
# CarCompany_plymouth      -0.0044      0.036     -0.122      0.903      -0.075       0.067
# CarCompany_porsche        0.0863      0.062      1.387      0.168      -0.037       0.209
# CarCompany_saab          -0.0206      0.044     -0.472      0.638      -0.107       0.066
# CarCompany_volvo         -0.0447      0.035     -1.267      0.208      -0.115       0.025
# ==============================================================================
# Omnibus:                       21.668   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.868
# Skew:                           0.565   Prob(JB):                     1.22e-12
# Kurtosis:                       5.817   Cond. No.                         39.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_new = X_train_new.drop(["CarCompany_dodge"], axis = 1)

# %%
# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

# %%
lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     65.40
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           6.63e-56
# Time:                        00:19:39   Log-Likelihood:                 196.68
# No. Observations:                 143   AIC:                            -349.4
# Df Residuals:                     121   BIC:                            -284.2
# Df Model:                          21
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2278      0.069     -3.314      0.001      -0.364      -0.092
# carwidth                  0.3739      0.077      4.872      0.000       0.222       0.526
# curbweight                0.6504      0.099      6.602      0.000       0.455       0.845
# boreratio                 0.0069      0.063      0.110      0.913      -0.118       0.132
# stroke                   -0.0830      0.056     -1.488      0.139      -0.193       0.027
# peakrpm                   0.0677      0.040      1.680      0.096      -0.012       0.147
# highwaympg                0.1057      0.065      1.636      0.104      -0.022       0.234
# cylindernumber_five      -0.0311      0.032     -0.983      0.328      -0.094       0.032
# cylindernumber_four      -0.0252      0.032     -0.779      0.437      -0.089       0.039
# cylindernumber_three      0.3141      0.099      3.185      0.002       0.119       0.509
# cylindernumber_twelve     0.1346      0.075      1.803      0.074      -0.013       0.282
# cylindernumber_two        0.0177      0.047      0.376      0.708      -0.076       0.111
# aspiration_turbo          0.0391      0.019      2.058      0.042       0.001       0.077
# enginelocation_rear       0.4871      0.096      5.082      0.000       0.297       0.677
# enginetype_l             -0.1806      0.035     -5.191      0.000      -0.249      -0.112
# enginetype_ohcf          -0.0609      0.037     -1.647      0.102      -0.134       0.012
# CarCompany_bmw            0.2542      0.033      7.713      0.000       0.189       0.319
# CarCompany_mitsubishi    -0.0573      0.026     -2.228      0.028      -0.108      -0.006
# CarCompany_plymouth      -0.0050      0.035     -0.142      0.888      -0.075       0.065
# CarCompany_porsche        0.0865      0.062      1.399      0.164      -0.036       0.209
# CarCompany_saab          -0.0207      0.043     -0.477      0.634      -0.107       0.065
# CarCompany_volvo         -0.0448      0.035     -1.277      0.204      -0.114       0.025
# ==============================================================================
# Omnibus:                       21.715   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.248
# Skew:                           0.564   Prob(JB):                     1.01e-12
# Kurtosis:                       5.828   Cond. No.                         39.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features     VIF
# 0                   const  152.80
# 2              curbweight   13.92
# 8     cylindernumber_four    6.49
# 1                carwidth    6.44
# 3               boreratio    5.53
# 6              highwaympg    4.76
# 15        enginetype_ohcf    3.39
# 19     CarCompany_porsche    2.54
# 4                  stroke    2.49
# 14           enginetype_l    2.31
# 9    cylindernumber_three    2.19
# 13    enginelocation_rear    2.06
# 5                 peakrpm    2.01
# 11     cylindernumber_two    1.95
# 7     cylindernumber_five    1.91
# 12       aspiration_turbo    1.74
# 21       CarCompany_volvo    1.60
# 16         CarCompany_bmw    1.41
# 17  CarCompany_mitsubishi    1.26
# 10  cylindernumber_twelve    1.25
# 20        CarCompany_saab    1.25
# 18    CarCompany_plymouth    1.09

# %%
X_train_new = X_train_new.drop(["boreratio"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     69.23
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           7.90e-57
# Time:                        00:19:39   Log-Likelihood:                 196.67
# No. Observations:                 143   AIC:                            -351.3
# Df Residuals:                     122   BIC:                            -289.1
# Df Model:                          20
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2280      0.068     -3.332      0.001      -0.363      -0.093
# carwidth                  0.3749      0.076      4.942      0.000       0.225       0.525
# curbweight                0.6550      0.089      7.393      0.000       0.480       0.830
# stroke                   -0.0823      0.055     -1.491      0.139      -0.192       0.027
# peakrpm                   0.0668      0.039      1.702      0.091      -0.011       0.144
# highwaympg                0.1045      0.063      1.649      0.102      -0.021       0.230
# cylindernumber_five      -0.0307      0.031     -0.981      0.329      -0.093       0.031
# cylindernumber_four      -0.0233      0.027     -0.856      0.394      -0.077       0.031
# cylindernumber_three      0.3168      0.095      3.331      0.001       0.129       0.505
# cylindernumber_twelve     0.1343      0.074      1.808      0.073      -0.013       0.281
# cylindernumber_two        0.0199      0.042      0.470      0.640      -0.064       0.104
# aspiration_turbo          0.0386      0.018      2.102      0.038       0.002       0.075
# enginelocation_rear       0.4859      0.095      5.128      0.000       0.298       0.673
# enginetype_l             -0.1805      0.035     -5.211      0.000      -0.249      -0.112
# enginetype_ohcf          -0.0586      0.031     -1.912      0.058      -0.119       0.002
# CarCompany_bmw            0.2554      0.031      8.178      0.000       0.194       0.317
# CarCompany_mitsubishi    -0.0572      0.026     -2.234      0.027      -0.108      -0.007
# CarCompany_plymouth      -0.0054      0.035     -0.156      0.876      -0.074       0.064
# CarCompany_porsche        0.0897      0.055      1.636      0.104      -0.019       0.198
# CarCompany_saab          -0.0198      0.042     -0.467      0.641      -0.104       0.064
# CarCompany_volvo         -0.0437      0.033     -1.308      0.193      -0.110       0.022
# ==============================================================================
# Omnibus:                       21.863   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.019
# Skew:                           0.566   Prob(JB):                     6.85e-13
# Kurtosis:                       5.850   Cond. No.                         36.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features     VIF
# 0                   const  152.70
# 2              curbweight   11.35
# 1                carwidth    6.35
# 7     cylindernumber_four    4.64
# 5              highwaympg    4.61
# 3                  stroke    2.46
# 14        enginetype_ohcf    2.36
# 13           enginetype_l    2.31
# 8    cylindernumber_three    2.05
# 12    enginelocation_rear    2.03
# 18     CarCompany_porsche    2.01
# 4                 peakrpm    1.92
# 6     cylindernumber_five    1.88
# 11       aspiration_turbo    1.64
# 10     cylindernumber_two    1.60
# 20       CarCompany_volvo    1.46
# 15         CarCompany_bmw    1.28
# 16  CarCompany_mitsubishi    1.26
# 9   cylindernumber_twelve    1.25
# 19        CarCompany_saab    1.21
# 17    CarCompany_plymouth    1.08

# %%
X_train_new = X_train_new.drop(["CarCompany_plymouth"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     73.46
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           9.18e-58
# Time:                        00:19:40   Log-Likelihood:                 196.66
# No. Observations:                 143   AIC:                            -353.3
# Df Residuals:                     123   BIC:                            -294.1
# Df Model:                          19
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2279      0.068     -3.344      0.001      -0.363      -0.093
# carwidth                  0.3757      0.075      4.984      0.000       0.227       0.525
# curbweight                0.6547      0.088      7.421      0.000       0.480       0.829
# stroke                   -0.0823      0.055     -1.497      0.137      -0.191       0.027
# peakrpm                   0.0659      0.039      1.704      0.091      -0.011       0.143
# highwaympg                0.1039      0.063      1.650      0.102      -0.021       0.229
# cylindernumber_five      -0.0305      0.031     -0.980      0.329      -0.092       0.031
# cylindernumber_four      -0.0233      0.027     -0.858      0.393      -0.077       0.030
# cylindernumber_three      0.3175      0.095      3.355      0.001       0.130       0.505
# cylindernumber_twelve     0.1341      0.074      1.812      0.072      -0.012       0.281
# cylindernumber_two        0.0203      0.042      0.481      0.631      -0.063       0.104
# aspiration_turbo          0.0382      0.018      2.108      0.037       0.002       0.074
# enginelocation_rear       0.4861      0.094      5.152      0.000       0.299       0.673
# enginetype_l             -0.1804      0.034     -5.230      0.000      -0.249      -0.112
# enginetype_ohcf          -0.0585      0.031     -1.916      0.058      -0.119       0.002
# CarCompany_bmw            0.2554      0.031      8.212      0.000       0.194       0.317
# CarCompany_mitsubishi    -0.0567      0.025     -2.240      0.027      -0.107      -0.007
# CarCompany_porsche        0.0897      0.055      1.644      0.103      -0.018       0.198
# CarCompany_saab          -0.0196      0.042     -0.462      0.645      -0.103       0.064
# CarCompany_volvo         -0.0434      0.033     -1.307      0.194      -0.109       0.022
# ==============================================================================
# Omnibus:                       21.889   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.733
# Skew:                           0.570   Prob(JB):                     7.90e-13
# Kurtosis:                       5.838   Cond. No.                         36.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features     VIF
# 0                   const  152.69
# 2              curbweight   11.34
# 1                carwidth    6.32
# 7     cylindernumber_four    4.64
# 5              highwaympg    4.60
# 3                  stroke    2.46
# 14        enginetype_ohcf    2.35
# 13           enginetype_l    2.31
# 8    cylindernumber_three    2.04
# 12    enginelocation_rear    2.03
# 17     CarCompany_porsche    2.01
# 4                 peakrpm    1.89
# 6     cylindernumber_five    1.88
# 11       aspiration_turbo    1.61
# 10     cylindernumber_two    1.59
# 19       CarCompany_volvo    1.46
# 15         CarCompany_bmw    1.28
# 9   cylindernumber_twelve    1.25
# 16  CarCompany_mitsubishi    1.24
# 18        CarCompany_saab    1.21

# %%
X_train_new = X_train_new.drop(["CarCompany_saab"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     78.02
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           1.14e-58
# Time:                        00:19:40   Log-Likelihood:                 196.54
# No. Observations:                 143   AIC:                            -355.1
# Df Residuals:                     124   BIC:                            -298.8
# Df Model:                          18
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2253      0.068     -3.327      0.001      -0.359      -0.091
# carwidth                  0.3718      0.075      4.980      0.000       0.224       0.520
# curbweight                0.6491      0.087      7.452      0.000       0.477       0.821
# stroke                   -0.0757      0.053     -1.430      0.155      -0.181       0.029
# peakrpm                   0.0640      0.038      1.669      0.098      -0.012       0.140
# highwaympg                0.1043      0.063      1.661      0.099      -0.020       0.229
# cylindernumber_five      -0.0298      0.031     -0.962      0.338      -0.091       0.032
# cylindernumber_four      -0.0266      0.026     -1.021      0.309      -0.078       0.025
# cylindernumber_three      0.3079      0.092      3.345      0.001       0.126       0.490
# cylindernumber_twelve     0.1390      0.073      1.904      0.059      -0.005       0.284
# cylindernumber_two        0.0193      0.042      0.460      0.646      -0.064       0.102
# aspiration_turbo          0.0374      0.018      2.079      0.040       0.002       0.073
# enginelocation_rear       0.4797      0.093      5.156      0.000       0.296       0.664
# enginetype_l             -0.1759      0.033     -5.333      0.000      -0.241      -0.111
# enginetype_ohcf          -0.0552      0.030     -1.865      0.064      -0.114       0.003
# CarCompany_bmw            0.2558      0.031      8.255      0.000       0.194       0.317
# CarCompany_mitsubishi    -0.0556      0.025     -2.212      0.029      -0.105      -0.006
# CarCompany_porsche        0.0935      0.054      1.738      0.085      -0.013       0.200
# CarCompany_volvo         -0.0399      0.032     -1.237      0.218      -0.104       0.024
# ==============================================================================
# Omnibus:                       22.799   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.623
# Skew:                           0.602   Prob(JB):                     3.07e-13
# Kurtosis:                       5.868   Cond. No.                         35.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features     VIF
# 0                   const  151.62
# 2              curbweight   11.13
# 1                carwidth    6.24
# 5              highwaympg    4.60
# 7     cylindernumber_four    4.31
# 3                  stroke    2.30
# 14        enginetype_ohcf    2.23
# 13           enginetype_l    2.12
# 12    enginelocation_rear    1.99
# 17     CarCompany_porsche    1.97
# 8    cylindernumber_three    1.95
# 4                 peakrpm    1.87
# 6     cylindernumber_five    1.87
# 10     cylindernumber_two    1.59
# 11       aspiration_turbo    1.59
# 18       CarCompany_volvo    1.38
# 15         CarCompany_bmw    1.28
# 16  CarCompany_mitsubishi    1.23
# 9   cylindernumber_twelve    1.23

# %%
X_train_new = X_train_new.drop(["cylindernumber_five"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     82.61
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           1.94e-59
# Time:                        00:19:40   Log-Likelihood:                 196.00
# No. Observations:                 143   AIC:                            -356.0
# Df Residuals:                     125   BIC:                            -302.7
# Df Model:                          17
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2366      0.067     -3.549      0.001      -0.368      -0.105
# carwidth                  0.3472      0.070      4.952      0.000       0.208       0.486
# curbweight                0.6737      0.083      8.097      0.000       0.509       0.838
# stroke                   -0.0741      0.053     -1.401      0.164      -0.179       0.031
# peakrpm                   0.0643      0.038      1.677      0.096      -0.012       0.140
# highwaympg                0.1089      0.063      1.740      0.084      -0.015       0.233
# cylindernumber_four      -0.0167      0.024     -0.698      0.487      -0.064       0.031
# cylindernumber_three      0.3116      0.092      3.389      0.001       0.130       0.494
# cylindernumber_twelve     0.1474      0.072      2.033      0.044       0.004       0.291
# cylindernumber_two        0.0310      0.040      0.772      0.441      -0.048       0.111
# aspiration_turbo          0.0322      0.017      1.876      0.063      -0.002       0.066
# enginelocation_rear       0.4753      0.093      5.116      0.000       0.291       0.659
# enginetype_l             -0.1736      0.033     -5.278      0.000      -0.239      -0.108
# enginetype_ohcf          -0.0533      0.030     -1.804      0.074      -0.112       0.005
# CarCompany_bmw            0.2624      0.030      8.690      0.000       0.203       0.322
# CarCompany_mitsubishi    -0.0527      0.025     -2.113      0.037      -0.102      -0.003
# CarCompany_porsche        0.1030      0.053      1.948      0.054      -0.002       0.208
# CarCompany_volvo         -0.0336      0.032     -1.064      0.289      -0.096       0.029
# ==============================================================================
# Omnibus:                       24.769   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.842
# Skew:                           0.637   Prob(JB):                     3.06e-15
# Kurtosis:                       6.098   Cond. No.                         34.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_new = X_train_new.drop(["cylindernumber_four"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     88.10
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           2.58e-60
# Time:                        00:19:40   Log-Likelihood:                 195.73
# No. Observations:                 143   AIC:                            -357.5
# Df Residuals:                     126   BIC:                            -307.1
# Df Model:                          16
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2587      0.059     -4.421      0.000      -0.374      -0.143
# carwidth                  0.3593      0.068      5.303      0.000       0.225       0.493
# curbweight                0.6904      0.080      8.681      0.000       0.533       0.848
# stroke                   -0.0771      0.053     -1.465      0.146      -0.181       0.027
# peakrpm                   0.0667      0.038      1.750      0.083      -0.009       0.142
# highwaympg                0.1056      0.062      1.696      0.092      -0.018       0.229
# cylindernumber_three      0.3487      0.075      4.662      0.000       0.201       0.497
# cylindernumber_twelve     0.1431      0.072      1.985      0.049       0.000       0.286
# cylindernumber_two        0.0420      0.037      1.139      0.257      -0.031       0.115
# aspiration_turbo          0.0313      0.017      1.833      0.069      -0.002       0.065
# enginelocation_rear       0.4937      0.089      5.554      0.000       0.318       0.670
# enginetype_l             -0.1851      0.028     -6.519      0.000      -0.241      -0.129
# enginetype_ohcf          -0.0567      0.029     -1.952      0.053      -0.114       0.001
# CarCompany_bmw            0.2672      0.029      9.104      0.000       0.209       0.325
# CarCompany_mitsubishi    -0.0554      0.025     -2.252      0.026      -0.104      -0.007
# CarCompany_porsche        0.0972      0.052      1.865      0.064      -0.006       0.200
# CarCompany_volvo         -0.0390      0.031     -1.279      0.203      -0.099       0.021
# ==============================================================================
# Omnibus:                       23.068   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.056
# Skew:                           0.592   Prob(JB):                     5.52e-14
# Kurtosis:                       5.974   Cond. No.                         29.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features     VIF
# 0                   const  113.80
# 2              curbweight    9.32
# 1                carwidth    5.16
# 5              highwaympg    4.55
# 3                  stroke    2.28
# 12        enginetype_ohcf    2.16
# 4                 peakrpm    1.85
# 15     CarCompany_porsche    1.85
# 10    enginelocation_rear    1.82
# 11           enginetype_l    1.58
# 9        aspiration_turbo    1.44
# 6    cylindernumber_three    1.29
# 16       CarCompany_volvo    1.24
# 8      cylindernumber_two    1.23
# 7   cylindernumber_twelve    1.20
# 14  CarCompany_mitsubishi    1.19
# 13         CarCompany_bmw    1.15

# %%
X_train_new = X_train_new.drop(["cylindernumber_two"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     93.67
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           4.94e-61
# Time:                        00:19:41   Log-Likelihood:                 194.99
# No. Observations:                 143   AIC:                            -358.0
# Df Residuals:                     127   BIC:                            -310.6
# Df Model:                          15
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2485      0.058     -4.293      0.000      -0.363      -0.134
# carwidth                  0.3624      0.068      5.347      0.000       0.228       0.497
# curbweight                0.6756      0.079      8.600      0.000       0.520       0.831
# stroke                   -0.0753      0.053     -1.429      0.155      -0.180       0.029
# peakrpm                   0.0730      0.038      1.932      0.056      -0.002       0.148
# highwaympg                0.0862      0.060      1.437      0.153      -0.032       0.205
# cylindernumber_three      0.3525      0.075      4.711      0.000       0.204       0.501
# cylindernumber_twelve     0.1417      0.072      1.964      0.052      -0.001       0.285
# aspiration_turbo          0.0300      0.017      1.762      0.081      -0.004       0.064
# enginelocation_rear       0.4927      0.089      5.536      0.000       0.317       0.669
# enginetype_l             -0.1832      0.028     -6.457      0.000      -0.239      -0.127
# enginetype_ohcf          -0.0579      0.029     -1.993      0.048      -0.115      -0.000
# CarCompany_bmw            0.2655      0.029      9.047      0.000       0.207       0.324
# CarCompany_mitsubishi    -0.0576      0.025     -2.347      0.020      -0.106      -0.009
# CarCompany_porsche        0.0945      0.052      1.813      0.072      -0.009       0.198
# CarCompany_volvo         -0.0408      0.031     -1.339      0.183      -0.101       0.020
# ==============================================================================
# Omnibus:                       21.470   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.201
# Skew:                           0.559   Prob(JB):                     1.70e-12
# Kurtosis:                       5.801   Cond. No.                         29.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features     VIF
# 0                   const  111.17
# 2              curbweight    9.07
# 1                carwidth    5.15
# 5              highwaympg    4.21
# 3                  stroke    2.28
# 11        enginetype_ohcf    2.16
# 14     CarCompany_porsche    1.85
# 9     enginelocation_rear    1.82
# 4                 peakrpm    1.81
# 10           enginetype_l    1.57
# 8        aspiration_turbo    1.43
# 6    cylindernumber_three    1.29
# 15       CarCompany_volvo    1.24
# 7   cylindernumber_twelve    1.20
# 13  CarCompany_mitsubishi    1.18
# 12         CarCompany_bmw    1.15

# %%
X_train_new = X_train_new.drop(["CarCompany_volvo"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     99.61
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           1.17e-61
# Time:                        00:19:41   Log-Likelihood:                 193.99
# No. Observations:                 143   AIC:                            -358.0
# Df Residuals:                     128   BIC:                            -313.5
# Df Model:                          14
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2468      0.058     -4.250      0.000      -0.362      -0.132
# carwidth                  0.3518      0.068      5.209      0.000       0.218       0.485
# curbweight                0.6635      0.078      8.476      0.000       0.509       0.818
# stroke                   -0.0547      0.051     -1.082      0.281      -0.155       0.045
# peakrpm                   0.0672      0.038      1.786      0.076      -0.007       0.142
# highwaympg                0.0777      0.060      1.299      0.196      -0.041       0.196
# cylindernumber_three      0.3434      0.075      4.594      0.000       0.195       0.491
# cylindernumber_twelve     0.1568      0.071      2.194      0.030       0.015       0.298
# aspiration_turbo          0.0258      0.017      1.533      0.128      -0.007       0.059
# enginelocation_rear       0.4812      0.089      5.416      0.000       0.305       0.657
# enginetype_l             -0.1741      0.028     -6.301      0.000      -0.229      -0.119
# enginetype_ohcf          -0.0505      0.029     -1.763      0.080      -0.107       0.006
# CarCompany_bmw            0.2697      0.029      9.211      0.000       0.212       0.328
# CarCompany_mitsubishi    -0.0560      0.025     -2.279      0.024      -0.105      -0.007
# CarCompany_porsche        0.1054      0.052      2.041      0.043       0.003       0.208
# ==============================================================================
# Omnibus:                       23.539   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.404
# Skew:                           0.626   Prob(JB):                     1.26e-13
# Kurtosis:                       5.899   Cond. No.                         29.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features     VIF
# 0                   const  111.11
# 2              curbweight    8.95
# 1                carwidth    5.08
# 5              highwaympg    4.16
# 3                  stroke    2.08
# 11        enginetype_ohcf    2.08
# 9     enginelocation_rear    1.81
# 14     CarCompany_porsche    1.80
# 4                 peakrpm    1.79
# 10           enginetype_l    1.48
# 8        aspiration_turbo    1.38
# 6    cylindernumber_three    1.28
# 13  CarCompany_mitsubishi    1.18
# 7   cylindernumber_twelve    1.17
# 12         CarCompany_bmw    1.14

# %%
X_train_new = X_train_new.drop(["highwaympg"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.915
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     106.6
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           2.55e-62
# Time:                        00:19:41   Log-Likelihood:                 193.05
# No. Observations:                 143   AIC:                            -358.1
# Df Residuals:                     129   BIC:                            -316.6
# Df Model:                          13
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.1860      0.034     -5.392      0.000      -0.254      -0.118
# carwidth                  0.3549      0.068      5.245      0.000       0.221       0.489
# curbweight                0.5975      0.060     10.005      0.000       0.479       0.716
# stroke                   -0.0465      0.050     -0.925      0.356      -0.146       0.053
# peakrpm                   0.0418      0.032      1.296      0.197      -0.022       0.105
# cylindernumber_three      0.3592      0.074      4.858      0.000       0.213       0.506
# cylindernumber_twelve     0.1629      0.072      2.277      0.024       0.021       0.304
# aspiration_turbo          0.0246      0.017      1.462      0.146      -0.009       0.058
# enginelocation_rear       0.4795      0.089      5.383      0.000       0.303       0.656
# enginetype_l             -0.1687      0.027     -6.159      0.000      -0.223      -0.115
# enginetype_ohcf          -0.0570      0.028     -2.015      0.046      -0.113      -0.001
# CarCompany_bmw            0.2662      0.029      9.107      0.000       0.208       0.324
# CarCompany_mitsubishi    -0.0585      0.025     -2.382      0.019      -0.107      -0.010
# CarCompany_porsche        0.1161      0.051      2.273      0.025       0.015       0.217
# ==============================================================================
# Omnibus:                       25.637   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.407
# Skew:                           0.718   Prob(JB):                     7.64e-14
# Kurtosis:                       5.842   Cond. No.                         26.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features    VIF
# 0                   const  39.02
# 2              curbweight   5.18
# 1                carwidth   5.07
# 3                  stroke   2.05
# 10        enginetype_ohcf   2.01
# 8     enginelocation_rear   1.81
# 13     CarCompany_porsche   1.76
# 9            enginetype_l   1.45
# 7        aspiration_turbo   1.38
# 4                 peakrpm   1.30
# 5    cylindernumber_three   1.24
# 12  CarCompany_mitsubishi   1.17
# 6   cylindernumber_twelve   1.16
# 11         CarCompany_bmw   1.13

# %%
X_train_new = X_train_new.drop(["stroke"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     115.5
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           3.54e-63
# Time:                        00:19:41   Log-Likelihood:                 192.58
# No. Observations:                 143   AIC:                            -359.2
# Df Residuals:                     130   BIC:                            -320.6
# Df Model:                          12
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2097      0.023     -9.059      0.000      -0.255      -0.164
# carwidth                  0.3453      0.067      5.167      0.000       0.213       0.477
# curbweight                0.5973      0.060     10.007      0.000       0.479       0.715
# peakrpm                   0.0462      0.032      1.451      0.149      -0.017       0.109
# cylindernumber_three      0.3554      0.074      4.816      0.000       0.209       0.501
# cylindernumber_twelve     0.1801      0.069      2.609      0.010       0.044       0.317
# aspiration_turbo          0.0228      0.017      1.365      0.175      -0.010       0.056
# enginelocation_rear       0.4630      0.087      5.308      0.000       0.290       0.636
# enginetype_l             -0.1627      0.027     -6.118      0.000      -0.215      -0.110
# enginetype_ohcf          -0.0402      0.022     -1.852      0.066      -0.083       0.003
# CarCompany_bmw            0.2702      0.029      9.354      0.000       0.213       0.327
# CarCompany_mitsubishi    -0.0625      0.024     -2.581      0.011      -0.110      -0.015
# CarCompany_porsche        0.1237      0.050      2.453      0.015       0.024       0.223
# ==============================================================================
# Omnibus:                       24.628   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.433
# Skew:                           0.713   Prob(JB):                     1.51e-12
# Kurtosis:                       5.665   Cond. No.                         23.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_new = X_train_new.drop(["aspiration_turbo"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     125.0
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           7.73e-64
# Time:                        00:19:41   Log-Likelihood:                 191.56
# No. Observations:                 143   AIC:                            -359.1
# Df Residuals:                     131   BIC:                            -323.6
# Df Model:                          11
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.2127      0.023     -9.201      0.000      -0.258      -0.167
# carwidth                  0.3511      0.067      5.249      0.000       0.219       0.483
# curbweight                0.6077      0.059     10.232      0.000       0.490       0.725
# peakrpm                   0.0449      0.032      1.406      0.162      -0.018       0.108
# cylindernumber_three      0.3524      0.074      4.762      0.000       0.206       0.499
# cylindernumber_twelve     0.1686      0.069      2.452      0.016       0.033       0.305
# enginelocation_rear       0.4652      0.087      5.316      0.000       0.292       0.638
# enginetype_l             -0.1562      0.026     -5.950      0.000      -0.208      -0.104
# enginetype_ohcf          -0.0384      0.022     -1.766      0.080      -0.081       0.005
# CarCompany_bmw            0.2645      0.029      9.224      0.000       0.208       0.321
# CarCompany_mitsubishi    -0.0522      0.023     -2.261      0.025      -0.098      -0.007
# CarCompany_porsche        0.1162      0.050      2.311      0.022       0.017       0.216
# ==============================================================================
# Omnibus:                       17.715   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.179
# Skew:                           0.510   Prob(JB):                     8.45e-09
# Kurtosis:                       5.280   Cond. No.                         23.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_new = X_train_new.drop(["peakrpm"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     136.3
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           1.71e-64
# Time:                        00:19:42   Log-Likelihood:                 190.49
# No. Observations:                 143   AIC:                            -359.0
# Df Residuals:                     132   BIC:                            -326.4
# Df Model:                          10
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.1907      0.017    -11.181      0.000      -0.224      -0.157
# carwidth                  0.3596      0.067      5.378      0.000       0.227       0.492
# curbweight                0.5899      0.058     10.128      0.000       0.475       0.705
# cylindernumber_three      0.3543      0.074      4.772      0.000       0.207       0.501
# cylindernumber_twelve     0.1718      0.069      2.491      0.014       0.035       0.308
# enginelocation_rear       0.4794      0.087      5.495      0.000       0.307       0.652
# enginetype_l             -0.1628      0.026     -6.280      0.000      -0.214      -0.111
# enginetype_ohcf          -0.0460      0.021     -2.175      0.031      -0.088      -0.004
# CarCompany_bmw            0.2618      0.029      9.115      0.000       0.205       0.319
# CarCompany_mitsubishi    -0.0509      0.023     -2.200      0.030      -0.097      -0.005
# CarCompany_porsche        0.1250      0.050      2.496      0.014       0.026       0.224
# ==============================================================================
# Omnibus:                       18.966   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.700
# Skew:                           0.554   Prob(JB):                     2.39e-09
# Kurtosis:                       5.332   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                  Features   VIF
# 0                   const  9.41
# 1                carwidth  4.89
# 2              curbweight  4.87
# 5     enginelocation_rear  1.71
# 10     CarCompany_porsche  1.67
# 6            enginetype_l  1.28
# 3    cylindernumber_three  1.24
# 7         enginetype_ohcf  1.11
# 4   cylindernumber_twelve  1.07
# 8          CarCompany_bmw  1.07
# 9   CarCompany_mitsubishi  1.02

# %%
X_train_new = X_train_new.drop(["carwidth"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new)

lm = sm.OLS(y_train,X_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.892
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     122.5
# Date:                Tue, 29 Jan 2019   Prob (F-statistic):           6.57e-60
# Time:                        00:19:42   Log-Likelihood:                 176.33
# No. Observations:                 143   AIC:                            -332.7
# Df Residuals:                     133   BIC:                            -303.0
# Df Model:                           9
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.1334      0.015     -9.103      0.000      -0.162      -0.104
# curbweight                0.8581      0.033     25.909      0.000       0.793       0.924
# cylindernumber_three      0.2933      0.081      3.634      0.000       0.134       0.453
# cylindernumber_twelve     0.1671      0.076      2.203      0.029       0.017       0.317
# enginelocation_rear       0.3550      0.093      3.837      0.000       0.172       0.538
# enginetype_l             -0.1590      0.028     -5.579      0.000      -0.215      -0.103
# enginetype_ohcf          -0.0476      0.023     -2.047      0.043      -0.094      -0.002
# CarCompany_bmw            0.2418      0.031      7.720      0.000       0.180       0.304
# CarCompany_mitsubishi    -0.0535      0.025     -2.102      0.037      -0.104      -0.003
# CarCompany_porsche        0.2027      0.053      3.843      0.000       0.098       0.307
# ==============================================================================
# Omnibus:                       18.356   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.064
# Skew:                          -0.139   Prob(JB):                     1.84e-17
# Kurtosis:                       6.586   Cond. No.                         17.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features   VIF
# 0                  const  5.75
# 4    enginelocation_rear  1.59
# 9     CarCompany_porsche  1.53
# 1             curbweight  1.30
# 5           enginetype_l  1.28
# 2   cylindernumber_three  1.21
# 6        enginetype_ohcf  1.11
# 3  cylindernumber_twelve  1.07
# 7         CarCompany_bmw  1.06
# 8  CarCompany_mitsubishi  1.02

# %%
X_train_new = X_train_new.drop(['const'], axis=1)

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                 Features   VIF
# 3    enginelocation_rear  1.60
# 8     CarCompany_porsche  1.56
# 0             curbweight  1.48
# 4           enginetype_l  1.33
# 1   cylindernumber_three  1.15
# 5        enginetype_ohcf  1.15
# 6         CarCompany_bmw  1.10
# 7  CarCompany_mitsubishi  1.05
# 2  cylindernumber_twelve  1.04

# %% [markdown]
# ### Since the R square and Adjusted R square value in Final Model is almost same which is 0.840 and 0.835 respectively with low p value (<0.05) and low VIF value (<5), we are selecting this as our Final Model.

# %% [markdown]
# ## Step 6: Residual Analysis of the train data
#
# So, now to check if the error terms are also normally distributed (which is infact, one of the major assumptions of linear regression), let us plot the histogram of the error terms and see what it looks like.

# %%
y_train_price = lm.predict(X_train_lm)

# %%
# Importing the required libraries for plots.
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5,0,'Errors')

# %% [markdown]
# ## Step 7:  Making Predictions

# %% [markdown]
# #### Applying the scaling on the test sets

# %%
# Apply scaler() to all the columns except the 'dummy' variables on test dataset

num_vars = ['symboling', 'wheelbase', 'carlength', 'carwidth','carheight','curbweight', 'enginesize','boreratio','stroke','compressionratio','horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']

car_test[num_vars] = scaler.transform(car_test[num_vars])

# %% [markdown]
# #### Dividing into X_test and y_test

# %%
y_test = car_test.pop('price')
X_test = car_test

# %%
# Now let's use our model to make predictions.

# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[X_train_new.columns]

# Adding a constant variable 
X_test_new = sm.add_constant(X_test_new)

# %%
# Making predictions
y_pred = lm.predict(X_test_new)

# %% [markdown]
# ## Step 8:  Model Evaluation

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)

# %%
# Calculate RMSE (root-mean-square error)

from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test, y_pred))

# %% [markdown]
# ## Summary
#
# We can see that the equation of our best fitted line is:
#
# $ price = 1.167  \times  enginesize + 0.250  \times  enginetype_rotor + 0.205 \times CarCompany bmw + 0.210 \times    CarCompany porsche $

# %% [markdown]
# Conclusion
#
# 1.	The R square and Adjusted R square value in Final Model is almost same which is 0.840 and 0.835 respectively which indicates that none of the parameters in final model are reduntant.
#
# 2.	Error term is also normally distributed.
#
# 3.	The RMSE value is 0.08968889190774182
#
# 4.	As we can see that the model seems to be stable, The variables that can affect price are:
#
# 1) enginesize
# 2) CarCompany_bmw
# 3) enginetype_rotor
# 4) CarName_porsche
